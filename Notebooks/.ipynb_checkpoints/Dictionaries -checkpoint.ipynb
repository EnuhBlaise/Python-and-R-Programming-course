# %% [markdown]
# # Definition
# Dictionaries are used to store information that have a relation for a example a name and phone number.
# These are stored in Key value relationships
# ![image.png](attachment:image.png) (image from pythontic.com)

# %%
Dict = {}
Dict = {"Kim": "Istanbul University", "Ali": "Osmangazi University", "Ismael":"Konya University"}
print(Dict) #printing the entire dictionary
print(Dict["Kim"])#printing a value in the dictionary
# Out:
# {'Kim': 'Istanbul University', 'Ali': 'Osmangazi University', 'Ismael': 'Konya University'}
# Istanbul University

# %%
#*Type of Values in Dictionaries*
#Python allows the values in a dictionary to be any type – string, integer, a list, another dictionary, boolean, etc. 
#However, keys must always be an immutable data type, such as strings, numbers, or tuples. 

Dict = {"Kim": "Istanbul University", #string and String
        "Age": 26, #String and integer combined
        "Favourite movies": ["Avengers", "Fisherman's Diary", "Annabel"],#String and Lists combined
        "Friend's Information": {"Sam": 26, "Steph": 35, "Ali": 48} #Nested Dictionaries
       }

# %%
Dict["Friend's Information"]
# Out:
# {'Sam': 26, 'Steph': 35, 'Ali': 48}

# %% [markdown]
# # Accessing Dictionary elements

# %%
Dict = {"Kim": "Istanbul University", #string and String
        "Age": 26, #String and integer combined
        "Favourite movies": ["Avengers", "Fisherman's Diary", "Annabel"],#String and Lists combined
        "Friend's Information": {"Sam": 26, "Steph": 35, "Ali": 48} #Nested Dictionaries
       }

 
Dict.keys()
 
Dict.values()
 
Dict.items()

Dict.get() # method to access a dictionary value if it exists.

Dict.pop() #using a key as an argument, it can remove a key value pair. Also returns the value it has removed.
# Out:
# dict_items([('Kim', 'Istanbul University'), ('Age', 26), ('Favourite movies', ['Avengers', "Fisherman's Diary", 'Annabel']), ("Friend's Information", {'Sam': 26, 'Steph': 35, 'Ali': 48})])

# %% [markdown]
# # Adding, removing, and modifying dictionary items

# %%
#Adding key-value pairs in a dictionary
Dict["Kubra"] = "Osmangazi University"

# %%
#modifying key-value pairs in a  dictionary
Dict["Kim"] = "Konya University"

# %%
#removing Key-value pairs
del Dict["Age"]
print(Dict)

# %% [markdown]
# # Nesting Dictionaries and Lists

# %%
Dict_1 = {"Kim": "Istanbul University", #string and String
        "Age": 26, #String and integer combined
        "Favourite movies": ["Avengers", "Fisherman's Diary", "Annabel"],#String and Lists combined
        "Friend's Information": {"Sam": 26, "Steph": 35, "Ali": 48} #Nested Dictionaries
       }

Dict_2 = {"Kubra": "Istanbul University", #string and String
        "Age": 20, #String and integer combined
        "Favourite movies": ["Evil Dead", "Annabel", "Fisherman's Diary"],#String and Lists combined
        "Friend's Information": {"Sam": 26, "Steph": 35, "Ali": 48} #Nested Dictionaries
       }

# %%
#two dictionaries in a list

List1 = [Dict_1, Dict_2]
List1
# Out:
# [{'Kim': 'Istanbul University',
#   'Age': 26,
#   'Favourite movies': ['Avengers', "Fisherman's Diary", 'Annabel'],
#   "Friend's Information": {'Sam': 26, 'Steph': 35, 'Ali': 48}},
#  {'Kubra': 'Istanbul University',
#   'Age': 20,
#   'Favourite movies': ['Evil Dead', 'Annabel', "Fisherman's Diary"],
#   "Friend's Information": {'Sam': 26, 'Steph': 35, 'Ali': 48}}]

# %% [markdown]
# # Iterating Dictionary Items

# %%
#iteration with a for loop (Iteration is possible over keys and Values)
for keys in Dict.keys(): #Dict.values() for values
    print(keys)
# Out:
# Istanbul University
# 26
# ['Avengers', "Fisherman's Diary", 'Annabel']
# {'Sam': 26, 'Steph': 35, 'Ali': 48}

# %%
for keys in Dict_1.keys(): #Dict.values() for values
    print(keys)

# %%
#iteration over both keys and values 
for items in Dict.items(): #Dict.values() for values
    print(items)  #returns response as tuples.
# Out:
# ('Kim', 'Istanbul University')
# ('Age', 26)
# ('Favourite movies', ['Avengers', "Fisherman's Diary", 'Annabel'])
# ("Friend's Information", {'Sam': 26, 'Steph': 35, 'Ali': 48})

# %% [markdown]
# # Dictionary comprehension

# %%
sq_numbers = {}
for a in range(5):
    sq_numbers[a] = a**2
    
print(sq_numbers)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
#With Dictionary comphrehensions
sq_numbers_2 = {x:x**2 for x in range(5)}
print(sq_numbers_2)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
#Two lists can be zip into a dictionary
List1 = ["a", "b", "c"]
List2 = ["x", "y", "z"]

List3 = zip(List1, List2)#forms an iterable object which can be acessed with a for loop

# %%
{x:y for x,y in List3}
# Out:
# {'a': 'x', 'b': 'y', 'c': 'z'}
